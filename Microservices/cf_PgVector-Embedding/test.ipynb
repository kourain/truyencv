# %%
import requests

url = "https://pgvector-gemma.maiquyen.name.vn/embed"

# %%
response = requests.post(url, json={"texts": ["trả về helloword cc à"]})
response
# Out:
# <Response [200]>

# %%
print(response.text)
# Out:
# {"inserted":{"mutationId":"1c4b7f41-3405-4a72-a0bf-553b9a6a467b"},"vectors":[{"id":"0","values":[-0.10728577524423599,-0.013079225085675716,0.01778053306043148,0.019266963005065918,0.0016463587526232004,0.06938724219799042,-0.01628127694129944,0.045111361891031265,0.015406996011734009,-0.05556683987379074,0.0231119766831398,0.0009246152476407588,-0.02829502709209919,0.021953290328383446,0.054488565772771835,0.005449589807540178,-0.0036683939397335052,-0.05517704784870148,-0.007786378730088472,0.008681914769113064,0.002831334713846445,-0.020730916410684586,0.0376935675740242,-0.0461445078253746,0.025458458811044693,-0.01878257654607296,-0.01027973648160696,0.00252185994759202,-0.0011366652324795723,0.02756589837372303,0.006119651719927788,0.014340914785861969,-0.043648455291986465,0.018357809633016586,-0.01077538076788187,-0.01334740873426199,-0.029094550758600235,-0.04241396114230156,0.018259501084685326,-0.06371962279081345,-0.06317681074142456,0.017631130293011665,-0.07391463965177
# ...
