# %%
# !git clone https://github.com/kourain/truyencv.git
# Out:
# fatal: destination path 'truyencv' already exists and is not an empty directory.

# %%
cd truyencv
# Out:
# /content/truyencv

# %%
ls
# Out:
# Admin-Flows.md  CDN/                FE/       Microservices/    TTS/
# BE/             Converter-Flows.md  GPT-OSS/  Service-manager/  User-Flows.md

# %%
# !git checkout AI_TTS
# Out:
# Already on 'AI_TTS'
# Your branch is up to date with 'origin/AI_TTS'.
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# ...

# %%
cd TTS
# Out:
# /content/truyencv/TTS

# %%
# !uv sync
# Out:
# Using CPython 3.11.14
# Creating virtual environment at: .venv
# Resolved 209 packages in 15.74s
# Prepared 205 packages in 2m 16s
# Installed 205 packages in 1.36s
#  + absl-py==2.3.1
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.3
#  + aiosignal==1.4.0
#  + annotated-doc==0.0.4
#  + annotated-types==0.7.0
#  + anyascii==0.3.3
#  + anyio==4.12.1
#  + asttokens==3.0.1
#  + attrs==25.4.0
#  + audioread==3.1.0
#  + babel==2.17.0
#  + bangla==0.0.5
#  + blinker==1.9.0
#  + blis==1.3.3
#  + bnnumerizer==0.0.2
#  + bnunicodenormalizer==0.1.7
#  + catalogue==2.0.10
#  + certifi==2026.1.4
#  + cffi==2.0.0
#  + charset-normalizer==3.4.4
#  + click==8.3.1
#  + cloudpathlib==0.23.0
#  + comm==0.2.3
#  + confection==0.1.5
#  + contourpy==1.3.3
#  + coqpit==0.0.17
#  + cupy-cuda12x==13.6.0
#  + cycler==0.12.1
#  + cymem==2.0.13
#  + cython==3.2.4
#  + datasets==4.4.2
#  + dateparser==1.1.8
#  + debugpy==1.8.17
#  + decorator==5.2.1
#  + deepspeed==0.18.4
#  + dill==0.4.0
#  + docopt==0.6.2
# ...

# %%
# !sudo apt update
# !sudo apt update && sudo apt install -y build-essential
# !sudo apt install -y ffmpeg libavcodec-dev libavformat-dev libavutil-dev libswscale-dev libavdevice-dev libavfilter-dev libswresample-dev

# install nvidia-cuda-toolkit
# !sudo apt install -y nvidia-cuda-toolkit
# !source cuda_venv
# !sudo ldconfig
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,864 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,591 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,289 kB]
# ...

# %%
import os 
os.environ['CUDA_HOME'] = os.path.dirname(os.path.dirname(os.popen('which nvcc').read().strip()))
os.environ['PATH'] = os.path.join(os.environ['CUDA_HOME'], 'bin') + ':' + os.environ.get('PATH', '')
os.environ['LD_LIBRARY_PATH'] = os.path.join(os.environ['CUDA_HOME'], 'lib64') + ':' + os.environ.get('LD_LIBRARY_PATH', '')
os.environ['VIRTUAL_ENV'] = '/content/truyencv/TTS/.venv'
os.environ['LD_LIBRARY_PATH'] = ':'.join([
    os.path.join(os.environ['VIRTUAL_ENV'], 'lib/python3.11/site-packages', subpath)
    for subpath in [
        'torch/lib',
        'nvidia/cuda_runtime/lib',
        'nvidia/cuda_cupti/lib',
        'nvidia/cuda_nvrtc/lib',
        'nvidia/cusparse/lib',
        'nvidia/cudnn/lib',
        'nvidia/cublas/lib',
        'nvidia/curand/lib',
        'nvidia/cusolver/lib',
        'nvidia/cufft/lib',
        'nvidia/cufile/lib',
        'nvidia/nvjitlink/lib',
        'nvidia/nvtx/lib',
        'nvidia/npp/lib'
    ]] + [os.environ.get('LD_LIBRARY_PATH', '')])

# %%
uv run prepare_ngochuyen_dataset.py
# Out:
# ...
# XTTS Dataset Preparation - ngochuyen_voice
# ...
# Dataset: pnnbao-ump/ngochuyen_voice
# Output: /content/truyencv/TTS/data/ngochuyen_voice
# Train/Val split: 95/5
# ...
# Đang tải dataset pnnbao-ump/ngochuyen_voice từ Hugging Face...
# Tổng số mẫu: 7540
# Đang xử lý 7540 mẫu audio...
# Train: 7163 mẫu (95.0%)
# Val: 377 mẫu (5.0%)
# Processing: 100% 7540/7540 [04:05<00:00, 30.72it/s]
#
# ✓ Hoàn tất!
#   Train manifest: /content/truyencv/TTS/data/ngochuyen_voice/metadata_train.csv (7163 mẫu)
#   Val manifest: /content/truyencv/TTS/data/ngochuyen_voice/metadata_val.csv (377 mẫu)
#   Audio files: /content/truyencv/TTS/data/ngochuyen_voice/wavs
#
# ...
# Tổng kết:
#   ✓ Train: 7163 mẫu
#   ✓ Val: 377 mẫu
#   ✓ Tổng: 7540 mẫu
# ...
#
# Bước tiếp theo:
# 1. Kiểm tra manifest files trong: /content/truyencv/TTS/data/ngochuyen_voice
# 2. Cập nhật config.json với đường dẫn dataset
# 3. Chạy training với notebook fine_tune_ngochuyen.ipynb

# %%
# Cài đặt gdown
# %pip install gdown

# Tải file
# !gdown 1g5zUcsLaOIsUo9gDxISbMxBrzyzJAX30 -O models/model.pth
# Out:
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1g5zUcsLaOIsUo9gDxISbMxBrzyzJAX30
# From (redirected): https://drive.google.com/uc?id=1g5zUcsLaOIsUo9gDxISbMxBrzyzJAX30&confirm=t&uuid=ea45d66b-adc6-4c56-a2dd-ff36b8beb9b3
# To: /content/truyencv/TTS/models/model.pth
# 100% 1.88G/1.88G [00:22<00:00, 82.2MB/s]

# %%
! uv run train_xtts_gpt.py
# Out:
# /content/truyencv/TTS/.venv/lib/python3.11/site-packages/transformers/utils/generic.py:311: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# /content/truyencv/TTS/.venv/lib/python3.11/site-packages/torch/cuda/__init__.py:827: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
#
# ...
# XTTS Fine-tuning Configuration
# ...
# Dataset: /content/truyencv/TTS/data/ngochuyen_voice
# Language: vi
# Epochs: 10
# Batch size: 1
# Output path: /content/truyencv/TTS/outputs/xtts_ngochuyen_ft/run/training
# ...
#
#  > Initializing GPTTrainer model...
# >> DVAE weights restored from: /content/truyencv/TTS/outputs/xtts_ngochuyen_ft/run/training/XTTS_v2.0_original_model_files/dvae.pth
#  > Loading training samples...
# ...
