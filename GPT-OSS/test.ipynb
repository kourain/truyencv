# %%
from typing import Literal
import requests


class _GPTOssResponse_Output_Content:
    def __init__(
        self,
        annotations: list | None = None,
        text: str | None = None,
        type: Literal["output_text", "reasoning_text"] | None = None,
        logprobs: list | None = None,
    ):
        self.annotations = annotations
        self.text = text
        self.type = type
        self.logprobs = logprobs


class _GPTOssResponse_OutPut:
    def __init__(
        self,
        id: str | None = None,
        content: list | None = None,
        summary: list | None = None,
        role: Literal["user", "assistant", "system"] | None = None,
        type: Literal["message", "reasoning_text"] | None = None,
        encrypted_content: str | None = None,
        status: str | None = None,
    ):
        self.id = id
        self.content = [
            _GPTOssResponse_Output_Content(**item) if isinstance(item, dict) else item
            for item in (content or [])
        ]
        self.summary = summary
        self.role = role
        self.type = type
        self.encrypted_content = encrypted_content
        self.status = status


class _GPTOssResponse_Usage:
    def __init__(
        self,
        input_tokens: int | None = None,
        output_tokens: int | None = None,
        total_tokens: int | None = None,
    ):
        self.input_tokens = input_tokens
        self.output_tokens = output_tokens
        self.total_tokens = total_tokens


class GPTOssResponse:
    def __init__(
        self,
        id: str | None = None,
        created_at: int | None = None,
        instructions: list | None = None,
        metadata: dict | None = None,
        model: str | None = None,
        object: Literal["response", "error"] | None = None,
        output: list | None = None,
        parallel_tool_calls: bool | None = None,
        temperature: float | None = None,
        tool_choice: str | None = None,
        tools: list | None = None,
        top_p: float | None = None,
        background: bool | None = None,
        max_output_tokens: int | None = None,
        max_tool_calls: int | None = None,
        previous_response_id: str | None = None,
        prompt: list | None = None,
        reasoning: list | None = None,
        service_tier: str | None = None,
        status: Literal["completed", "failed", "pending"] | None = None,
        text: str | None = None,
        top_logprobs: int | None = None,
        truncation: Literal["disabled", "enabled"] | None = None,
        usage: dict | None = None,
        user: str | None = None,
    ):
        self.id = id
        self.created_at = created_at
        self.instructions = instructions
        self.metadata = metadata
        self.model = model
        self.object = object
        self.output = [
            _GPTOssResponse_OutPut(**item) if isinstance(item, dict) else item
            for item in (output or [])
        ]
        self.parallel_tool_calls = parallel_tool_calls
        self.temperature = temperature
        self.tool_choice = tool_choice
        self.tools = tools
        self.top_p = top_p
        self.background = background
        self.max_output_tokens = max_output_tokens
        self.max_tool_calls = max_tool_calls
        self.previous_response_id = previous_response_id
        self.prompt = prompt
        self.reasoning = reasoning
        self.service_tier = service_tier
        self.status = status
        self.text = text
        self.top_logprobs = top_logprobs
        self.truncation = truncation
        self.usage = (
            _GPTOssResponse_Usage(**usage) if isinstance(usage, dict) else usage
        )
        self.user = user

# %%
messages = [
    {
        "role": "system",
        "content": "Bạn là một trợ lý hữu ích. Ngôn ngữ sử dụng là tiếng Việt.",
    },
    {
        "role": "user",
        "content": """viết lại cho tôi văn bản sau mà không thay đổi ý nghĩa của nó:
     ```Tôi xin cam đoan đề tài “Ứng dụng mô hình ngôn ngữ lớn cho bài toán chuyển đổi văn phong văn bản truyện” là sản phẩm đồ án tốt nghiệp đại học ngành công nghệ thông tin do tôi nghiên cứu và thực hiện dưới sự hướng dẫn và giám sát của ThS. Nguyễn Thị Minh Tâm. Các nội dung nghiên cứu, kết quả đạt được trong đề tài này là hoàn toàn trung thực và chưa được công bố dưới bất cứ hình thức nào từ trước đây đến nay. 
Nếu phát hiện có bất kỳ sự gian lận nào tôi xin hoàn toàn chịu trách nhiệm về nội dung của đề tài và xin chịu mọi hình thức kỷ luật của Viện Kỹ thuật Công nghệ và Trường Đại học Vinh.```""",
    },
]

# %%
response = requests.post(
    "https://ai.maiquyen.name.vn/api/chat",
    json={
        "model": "@openai/gpt-oss-120b",
        # "lora_adapter": "@maiquyen/cdn/gpt-oss-adapter/adapter_lora_l32r16.bin",
        # "lora_adapter_config": "@maiquyen/cdn/gpt-oss-adapter/adapter_config.json",
        "messages": messages + [{"role": "user", "content": "Câu trả lời đâu?"}],
        "temperature": 1,
        "top_p": 1,
    },
)

# %%
resp = GPTOssResponse(**response.json())
assistant_text = (
    resp.output[0].content[0].text if resp.output and resp.output[0].content else None
)
if assistant_text:
    messages.append({"role": "assistant", "content": assistant_text})
messages
# Out:
# [{'role': 'system',
#   'content': 'Bạn là một trợ lý hữu ích. Ngôn ngữ sử dụng là tiếng Việt.'},
#  {'role': 'user',
#   'content': 'viết lại cho tôi văn bản sau mà không thay đổi ý nghĩa của nó:\n     ```Tôi xin cam đoan đề tài “Ứng dụng mô hình ngôn ngữ lớn cho bài toán chuyển đổi văn phong văn bản truyện” là sản phẩm đồ án tốt nghiệp đại học ngành công nghệ thông tin do tôi nghiên cứu và thực hiện dưới sự hướng dẫn và giám sát của ThS. Nguyễn Thị Minh Tâm. Các nội dung nghiên cứu, kết quả đạt được trong đề tài này là hoàn toàn trung thực và chưa được công bố dưới bất cứ hình thức nào từ trước đây đến nay. \nNếu phát hiện có bất kỳ sự gian lận nào tôi xin hoàn toàn chịu trách nhiệm về nội dung của đề tài và xin chịu mọi hình thức kỷ luật của Viện Kỹ thuật Công nghệ và Trường Đại học Vinh.```'},
#  {'role': 'assistant',
#   'content': 'The user wants rewrite the text without changing meaning, in Vietnamese. Provide paraphrased version. Ensure no policy issues. Just rewrite.'}]

# %%
response.json()
# Out:
# {'id': 'resp_b118259ccb8e4c29bc1fece617c909b0',
#  'created_at': 1766722728,
#  'instructions': None,
#  'metadata': None,
#  'model': '@cf/openai/gpt-oss-120b',
#  'object': 'response',
#  'output': [{'id': 'rs_db221606242b4f29b12356a72caa871b',
#    'content': [{'text': 'The user first asked: "Cho tôi thời gian chi tiết hiện tại ở Việt Nam." (Give me the detailed current time in Vietnam.) Then user asks: "Tôi vừa hỏi gì?" (What did I just ask?) So they ask what was their previous question. We need to answer: they asked for the current detailed time in Vietnam. Also maybe provide the time? The user asked now "What did I just ask?" So answer that. Possibly also give the answer could include the time if needed? But question is just what they asked. So respond in Vietnamese: "Bạn vừa hỏi thời gian chi tiết hiện tại ở Việt Nam." Provide maybe also answer the time? Not asked, but maybe helpful. Could also give the time. Probably just answer the question.',
# ...

# %%
temp_resp = GPTOssResponse(**response.json())
temp_resp.output[0].content[0].text
# Out:
# 'We need to provide the rewritten text. Ensure same meaning, not altering. Provide in Vietnamese. We\'ll paraphrase.\n\nOriginal:\n\n"Tôi xin cam đoan đề tài “Ứng dụng mô hình ngôn ngữ lớn cho bài toán chuyển đổi văn phong văn bản truyện” là sản phẩm đồ án tốt nghiệp đại học ngành công nghệ thông tin do tôi nghiên cứu và thực hiện dưới sự hướng dẫn và giám sát của ThS. Nguyễn Thị Minh Tâm. Các nội dung nghiên cứu, kết quả đạt được trong đề tài này là hoàn toàn trung thực và chưa được công bố dưới bất cứ hình thức nào từ trước đây đến nay. \nNếu phát hiện có bất kỳ sự gian lận nào tôi xin hoàn toàn chịu trách nhiệm về nội dung của đề tài và xin chịu mọi hình thức kỷ luật của Viện Kỹ thuật Công nghệ và Trường Đại học Vinh."\n\nWe need rewrite. Provide paraphrased version.\n\nWe\'ll keep content, improve phrasing.\n\nLet\'s draft.\n\n"고:"\n\nLet\'s produce final answer.'
